# %%
import os
import librosa
import numpy as np
import pandas as pd
import json
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Concatenate, Input
from tensorflow.keras.models import Model
from sklearn.model_selection import train_test_split
from tqdm import tqdm
from pathlib import Path
from textblob import TextBlob
import soundfile as sf
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
# Out:
# WARNING:tensorflow:From C:\Users\Lenovo\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
import warnings                    # built‑in module

# Turn off *all* warnings:
warnings.filterwarnings("ignore")

# %%
BASE_DIR = Path.cwd()
AUDIO_DIR = BASE_DIR / "Processed"  # Directory where audio files are saved
TEXT_DIR = BASE_DIR / "Processed"   # Directory where transcript files are saved
SAVED_MODEL_PATH = "multimodal_depression_model.h5"

# %%
LABELS={
    "300": 0,
    "301": 0,
    "302": 0,
    "303": 0,
    "304": 0,
    "308": 1,
    "309": 1,
    "310": 0,
    "311": 1,
    "312": 0,
    "313": 0,
    "314": 0,
    "315": 0,
    "316": 0,
    "317": 0,
    "318": 0,
    "319": 1,
    "320": 1,
    "321": 1,
    "322": 0,
    "323": 0,
    "324": 0,
    "325": 1,
    "326": 0,
    "327": 0,
    "328": 0,
    "329": 0,
    "330": 1,
    "331": 0,
    "332": 1,
    "334": 0,
    "335": 1,
    "336": 0,
    "337": 1,
    "338": 1,
    "339": 1,
    "340": 0,
    "341": 0,
    "343": 0,
    "344": 1,
    "345": 1,
    "346": 1,
    "347": 1,
    "348": 1,
    "349": 0,
    "350": 1,
    "351": 1,
    "352": 1,
    "353": 1,
    "354": 1,
    "355": 1,
    "356": 1,
    "357": 0,
    "358": 0,
    "359": 1,
    "360": 0,
    "361": 0,
    "362": 1,
    "363": 0,
    "364": 0,
    "365": 1,
    "366": 0,
    "367": 1,
    "368": 0,
    "369": 0,
    "370": 0,
    "371": 0,
    "372": 1,
    "373": 0,
    "374": 0,
    "375": 0,
    "376": 1,
    "377": 1,
    "378": 0,
    "379": 0,
    "381": 1,
    "382": 0,
    "383": 0,
    "446": 0,
    "447": 0,
    "448": 1
}

# %%
def extract_audio_features(file_path):
    y, sr = librosa.load(file_path, sr=None)
    mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=13)
    return np.mean(mfccs, axis=1)

# Function to extract text features (Sentiment, Word Lengths, etc.)
def extract_text_features(file_path):
    with open(file_path, "r", encoding="utf8") as f:
        rows = json.load(f)  # load the JSON file created in the transcript processing
        print(f"Loaded data: {rows}")  # Debugging line

    # Check if data is a list or a dictionary
    if isinstance(rows, dict):
        # Assuming the file contains a dictionary instead of a list of dictionaries
        text = rows.get("text", "")
    elif isinstance(rows, list):
        # Assuming the file contains a list of rows (each with a 'text' key)
        text = ' '.join([row.get("text", "") for row in rows if "text" in row])
    else:
        raise ValueError("Unexpected data structure in JSON file")

    # Extract text features (Sentiment analysis using TextBlob)
    blob = TextBlob(text)
    polarity = blob.sentiment.polarity
    subjectivity = blob.sentiment.subjectivity
    return np.array([polarity, subjectivity])

# %%
import os

available_ids = []
for filename in os.listdir(AUDIO_DIR):
    if filename.endswith("_p.wav"):
        pid = filename.split("_")[0]
        available_ids.append(pid)

print(f"Total audio files found: {len(available_ids)}")
# Out:
# Total audio files found: 81

# %%
audio_features = []
text_features = []
labels = []

# Loop over the labels for the specified participants
for participant_id, label in LABELS.items():
    # Paths to the audio and text files
    audio_file = os.path.join(AUDIO_DIR, f"{participant_id}_p.wav")  # Assuming processed audio files
    text_file = os.path.join(TEXT_DIR, f"{participant_id}_transcript_features.json")  # Text features from the previous step

    if not os.path.exists(audio_file) or not os.path.exists(text_file):
        print(f"Skipping participant {participant_id}, missing files.")
        continue
    
    # Extract features
    audio_features.append(extract_audio_features(audio_file))
    text_features.append(extract_text_features(text_file))
    labels.append(label)
# Out:
# Loaded data: {'polarity_mean': 0.12626169328755535, 'polarity_std': 0.28250398287050743, 'subjectivity_mean': 0.2378644304290856, 'subjectivity_std': 0.331034277905171, 'len_char_mean': 12.913793103448276, 'len_char_std': 12.295895949685866, 'len_words_mean': 2.281609195402299, 'len_words_std': 2.0360921845440108, 'noun_ratio_mean': 0.4424169859514687, 'noun_ratio_std': 0.4049636976376597, 'verb_ratio_mean': 0.1446975916803503, 'verb_ratio_std': 0.23454448994722535, 'duration_total': 584.6800000000001, 'participant': '300'}
# Loaded data: {'polarity_mean': 0.11830665076176126, 'polarity_std': 0.3024703120781089, 'subjectivity_mean': 0.319622398013282, 'subjectivity_std': 0.34715560173034643, 'len_char_mean': 29.740331491712706, 'len_char_std': 37.35005544991499, 'len_words_mean': 5.138121546961326, 'len_words_std': 6.29441858639063, 'noun_ratio_mean': 0.4263969933305288, 'noun_ratio_std': 0.3637257463961745, 'verb_ratio_mean': 0.1382527532723798, 'verb_ratio_std': 0.186540474681985, 'duration_total': 774.4, 'participant': '301'}
# Loaded data: {'polarity_mean': 0.10716214565004886, 'polarity_std': 0.2517110301684378, 'subjectivity_mean': 0.23965617193439773, 'subjectivity_std': 0.3179096667031881, 'len_char_mean': 16.56989247311828, 'len_char_std': 16.71374113390172, 'len_words_mean': 2.8440860215053765, 'len_words_std': 2.6594842973207076, 'noun_ratio_mean': 0.49086912191750903, 'noun_ratio_std': 0.37459047429662823, 'verb_ratio_mean': 0.15982841829616024, 'verb_ratio_std': 0.23414007773806794, 'duration_total': 676.97, 'participant': '302'}
# Loaded data: {'polarity_mean': 0.12149847389376184, 'polarity_std': 0.2709073349167124, 'subjectivity_mean': 0.285303244360836, 'subjectivity_std': 0.32517934216105093, 'len_char_mean': 36.79057591623037, 'len_char_std': 57.63823762950248, 'len_words_mean': 6.507853403141361, 'len_words_std': 9.827924292249394, 'noun_ratio_mean': 0.4494014765975683, 'noun_ratio_std': 0.36650833292317897, 'verb_ratio_mean': 0.1639855329911794, 'verb_ratio_std': 0.21261979058926972, 'duration_total': 934.1, 'participant': '303'}
# Loaded data: {'polarity_mean': 0.10419299569575306, 'polarity_std': 0.26511497062866796, 'subjectivity_mean': 0.2604665262569674, 'subjectivity_std': 0.33010287015769185, 'len_char_mean': 20.995098039215687, 'len_char_std': 34.22289982459308, 'len_words_mean': 3.6127450980392157, 'len_words_std': 5.4031585648189955, 'noun_ratio_mean': 0.45005857965434837, 'noun_ratio_std': 0.38270213661264274, 'verb_ratio_mean': 0.1251206709988347, 'verb_ratio_std': 0.20454489080670932, 'duration_total': 720.04, 'participant': '304'}
# Loaded data: {'polarity_mean': 0.06457310670480312, 'polarity_std': 0.245409160340882, 'subjectivity_mean': 0.19531819040747614, 'subjectivity_std': 0.3110957792235147, 'len_char_mean': 16.915178571428573, 'len_char_std': 18.2979070077654, 'len_words_mean': 2.955357142857143, 'len_words_std': 3.0683934618786135, 'noun_ratio_mean': 0.4361458234226091, 'noun_ratio_std': 0.37573103038466565, 'verb_ratio_mean': 0.16427077386898814, 'verb_ratio_std': 0.25824331222067726, 'duration_total': 805.737, 'participant': '308'}
# Loaded data: {'polarity_mean': 0.08582730716253442, 'polarity_std': 0.2838745902074413, 'subjectivity_mean': 0.24062622983077528, 'subjectivity_std': 0.3141629798398968, 'len_char_mean': 19.176136363636363, 'len_char_std': 26.114641735758365, 'len_words_mean': 3.3011363636363638, 'len_words_std': 4.405866071972211, 'noun_ratio_mean': 0.46026287680808425, 'noun_ratio_std': 0.37507704137991654, 'verb_ratio_mean': 0.1564765850091937, 'verb_ratio_std': 0.20858520592846874, 'duration_total': 624.139, 'participant': '309'}
# Loaded data: {'polarity_mean': 0.09109277296777298, 'polarity_std': 0.2674854320902814, 'subjectivity_mean': 0.2299196203102453, 'subjectivity_std': 0.3193848401424857, 'len_char_mean': 19.479166666666668, 'len_char_std': 21.30667640796413, 'len_words_mean': 3.35, 'len_words_std': 3.6192188065761504, 'noun_ratio_mean': 0.5028936238340264, 'noun_ratio_std': 0.37638196837638394, 'verb_ratio_mean': 0.15971687461432044, 'verb_ratio_std': 0.21801084464828444, 'duration_total': 782.9250000000001, 'participant': '310'}
# Loaded data: {'polarity_mean': 0.07630061678734244, 'polarity_std': 0.2649185634746119, 'subjectivity_mean': 0.2121548620995524, 'subjectivity_std': 0.3077172150039194, 'len_char_mean': 14.305309734513274, 'len_char_std': 13.204701793648866, 'len_words_mean': 2.5707964601769913, 'len_words_std': 2.1963274969691944, 'noun_ratio_mean': 0.4318148297130598, 'noun_ratio_std': 0.3677477831057608, 'verb_ratio_mean': 0.12719866171193603, 'verb_ratio_std': 0.19224994986706803, 'duration_total': 717.997, 'participant': '311'}
# Loaded data: {'polarity_mean': 0.1437492956778671, 'polarity_std': 0.3036564349788296, 'subjectivity_mean': 0.29384204860395335, 'subjectivity_std': 0.3233189534232392, 'len_char_mean': 23.047619047619047, 'len_char_std': 29.6390990159315, 'len_words_mean': 3.861904761904762, 'len_words_std': 4.692962887211319, 'noun_ratio_mean': 0.4857254971877926, 'noun_ratio_std': 0.38874572229522303, 'verb_ratio_mean': 0.13191056568212695, 'verb_ratio_std': 0.20198292744747956, 'duration_total': 719.12, 'participant': '312'}
# Loaded data: {'polarity_mean': 0.11962819348182042, 'polarity_std': 0.278250963929062, 'subjectivity_mean': 0.2644210330544527, 'subjectivity_std': 0.33813411431694423, 'len_char_mean': 17.66839378238342, 'len_char_std': 21.31641303301584, 'len_words_mean': 3.0310880829015545, 'len_words_std': 3.4048169550519627, 'noun_ratio_mean': 0.4165715456442369, 'noun_ratio_std': 0.37052602859995687, 'verb_ratio_mean': 0.13660369693972255, 'verb_ratio_std': 0.20581676828190887, 'duration_total': 673.095, 'participant': '313'}
# Loaded data: {'polarity_mean': 0.0977672444033909, 'polarity_std': 0.2744409286882788, 'subjectivity_mean': 0.24229522247038174, 'subjectivity_std': 0.32035091880373584, 'len_char_mean': 21.38216560509554, 'len_char_std': 19.311732195910313, 'len_words_mean': 3.6008492569002124, 'len_words_std': 3.1666344508505047, 'noun_ratio_mean': 0.3739851930606895, 'noun_ratio_std': 0.33665587046038176, 'verb_ratio_mean': 0.15576803197634967, 'verb_ratio_std': 0.20832625310979075, 'duration_total': 1513.3890000000001, 'participant': '314'}
# Loaded data: {'polarity_mean': 0.1298725355435735, 'polarity_std': 0.3048975062857742, 'subjectivity_mean': 0.294199110041744, 'subjectivity_std': 0.34238795672787936, 'len_char_mean': 22.995535714285715, 'len_char_std': 27.94076016566998, 'len_words_mean': 3.9017857142857144, 'len_words_std': 4.507014605415352, 'noun_ratio_mean': 0.44411014369325824, 'noun_ratio_std': 0.3688237283465637, 'verb_ratio_mean': 0.15934328058146338, 'verb_ratio_std': 0.22107318051085878, 'duration_total': 899.87, 'participant': '315'}
# Loaded data: {'polarity_mean': 0.09910435043803245, 'polarity_std': 0.2811688439965003, 'subjectivity_mean': 0.25353769312974334, 'subjectivity_std': 0.34696367759737473, 'len_char_mean': 13.93723849372385, 'len_char_std': 13.278221661551735, 'len_words_mean': 2.4560669456066946, 'len_words_std': 2.1037069152844046, 'noun_ratio_mean': 0.49661453144716744, 'noun_ratio_std': 0.3852939963167997, 'verb_ratio_mean': 0.14456731088530253, 'verb_ratio_std': 0.2308260832675598, 'duration_total': 801.65, 'participant': '316'}
# Loaded data: {'polarity_mean': 0.08442408391272026, 'polarity_std': 0.26447358089531875, 'subjectivity_mean': 0.24737892999256636, 'subjectivity_std': 0.3366368743331103, 'len_char_mean': 16.72222222222222, 'len_char_std': 16.7655863117507, 'len_words_mean': 2.8181818181818183, 'len_words_std': 2.638503022601431, 'noun_ratio_mean': 0.4270089057967846, 'noun_ratio_std': 0.3715240176721971, 'verb_ratio_mean': 0.14317562347865379, 'verb_ratio_std': 0.21057648097036732, 'duration_total': 735.1099999999999, 'participant': '317'}
# Loaded data: {'polarity_mean': 0.18019151574405196, 'polarity_std': 0.2879495997843983, 'subjectivity_mean': 0.310847371227806, 'subjectivity_std': 0.3458109439210794, 'len_char_mean': 23.579710144927535, 'len_char_std': 22.99533802139665, 'len_words_mean': 4.0144927536231885, 'len_words_std': 3.811211863988918, 'noun_ratio_mean': 0.4697833523684185, 'noun_ratio_std': 0.358363496214264, 'verb_ratio_mean': 0.14698540799675014, 'verb_ratio_std': 0.18546030555982376, 'duration_total': 515.6600000000001, 'participant': '318'}
# Loaded data: {'polarity_mean': 0.11555318934351193, 'polarity_std': 0.3025793207714786, 'subjectivity_mean': 0.2670225682322457, 'subjectivity_std': 0.3365011274520047, 'len_char_mean': 17.370967741935484, 'len_char_std': 15.53677472283559, 'len_words_mean': 3.064516129032258, 'len_words_std': 2.577685748623629, 'noun_ratio_mean': 0.4671581703839768, 'noun_ratio_std': 0.3741017524737454, 'verb_ratio_mean': 0.1631137082749986, 'verb_ratio_std': 0.2188755439804549, 'duration_total': 599.79, 'participant': '319'}
# Loaded data: {'polarity_mean': 0.07638099103277675, 'polarity_std': 0.3256317295513642, 'subjectivity_mean': 0.2609991668384526, 'subjectivity_std': 0.3470320419881211, 'len_char_mean': 13.357142857142858, 'len_char_std': 12.71190079866117, 'len_words_mean': 2.3607142857142858, 'len_words_std': 2.07957110371885, 'noun_ratio_mean': 0.43533588435374154, 'noun_ratio_std': 0.3960327895325974, 'verb_ratio_mean': 0.155531462585034, 'verb_ratio_std': 0.23579056104544407, 'duration_total': 806.01, 'participant': '320'}
# Loaded data: {'polarity_mean': 0.09205825886083396, 'polarity_std': 0.302133331727767, 'subjectivity_mean': 0.25782711446874534, 'subjectivity_std': 0.335752505462922, 'len_char_mean': 17.536480686695278, 'len_char_std': 19.521422794096623, 'len_words_mean': 3.0472103004291844, 'len_words_std': 3.146207820463966, 'noun_ratio_mean': 0.4526785366483941, 'noun_ratio_std': 0.3743554034321311, 'verb_ratio_mean': 0.17389906360162408, 'verb_ratio_std': 0.22820658082184822, 'duration_total': 759.185, 'participant': '321'}
# Loaded data: {'polarity_mean': 0.09866009823103923, 'polarity_std': 0.26785388010283745, 'subjectivity_mean': 0.20503400744929268, 'subjectivity_std': 0.3113658984407761, 'len_char_mean': 18.160409556313994, 'len_char_std': 18.246735563815204, 'len_words_mean': 3.1467576791808876, 'len_words_std': 2.9958243884483595, 'noun_ratio_mean': 0.39940969155986217, 'noun_ratio_std': 0.356998494944432, 'verb_ratio_mean': 0.20409477704699547, 'verb_ratio_std': 0.25666532136198666, 'duration_total': 981.3779999999999, 'participant': '322'}
# Loaded data: {'polarity_mean': 0.17524515510610694, 'polarity_std': 0.33636540426001915, 'subjectivity_mean': 0.32469502528562166, 'subjectivity_std': 0.3341917489573695, 'len_char_mean': 25.091743119266056, 'len_char_std': 29.055339312588547, 'len_words_mean': 4.2889908256880735, 'len_words_std': 4.7064978996253775, 'noun_ratio_mean': 0.42103532165517593, 'noun_ratio_std': 0.3428231091984836, 'verb_ratio_mean': 0.1536697303716456, 'verb_ratio_std': 0.20962016861965327, 'duration_total': 740.4499999999999, 'participant': '323'}
# Loaded data: {'polarity_mean': 0.09207335633116884, 'polarity_std': 0.2917173470547695, 'subjectivity_mean': 0.2139742148042929, 'subjectivity_std': 0.31067277603719984, 'len_char_mean': 14.8671875, 'len_char_std': 13.3659626788845, 'len_words_mean': 2.59375, 'len_words_std': 2.1995988939162627, 'noun_ratio_mean': 0.48530410561660553, 'noun_ratio_std': 0.3738293837501176, 'verb_ratio_mean': 0.16557468139499387, 'verb_ratio_std': 0.231863421689, 'duration_total': 642.13, 'participant': '324'}
# Loaded data: {'polarity_mean': 0.17815035385962355, 'polarity_std': 0.3219958062497236, 'subjectivity_mean': 0.397153470229313, 'subjectivity_std': 0.33537265923920445, 'len_char_mean': 37.561797752808985, 'len_char_std': 38.81317123292818, 'len_words_mean': 6.219101123595506, 'len_words_std': 6.246560660988667, 'noun_ratio_mean': 0.4393381869928383, 'noun_ratio_std': 0.33213266584327694, 'verb_ratio_mean': 0.1916921391265122, 'verb_ratio_std': 0.20681660336115382, 'duration_total': 820.34, 'participant': '325'}
# Loaded data: {'polarity_mean': 0.13311194861068598, 'polarity_std': 0.266137959488188, 'subjectivity_mean': 0.23302554161140018, 'subjectivity_std': 0.3157397564891178, 'len_char_mean': 15.919191919191919, 'len_char_std': 17.862234651769036, 'len_words_mean': 2.712121212121212, 'len_words_std': 2.862846998976326, 'noun_ratio_mean': 0.5344516594516594, 'noun_ratio_std': 0.38598324903926323, 'verb_ratio_mean': 0.14086099086099088, 'verb_ratio_std': 0.21518777369326522, 'duration_total': 614.37, 'participant': '326'}
# Loaded data: {'polarity_mean': 0.16289475365903938, 'polarity_std': 0.3203684715258703, 'subjectivity_mean': 0.3222458359101216, 'subjectivity_std': 0.3371802864846032, 'len_char_mean': 22.102857142857143, 'len_char_std': 22.512084694826925, 'len_words_mean': 3.834285714285714, 'len_words_std': 3.793668565157743, 'noun_ratio_mean': 0.47000849273582573, 'noun_ratio_std': 0.36102494552162834, 'verb_ratio_mean': 0.14960820279528816, 'verb_ratio_std': 0.1885399159713142, 'duration_total': 619.9599999999999, 'participant': '327'}
# Loaded data: {'polarity_mean': 0.16258233217529436, 'polarity_std': 0.3435222674189899, 'subjectivity_mean': 0.34664513532685803, 'subjectivity_std': 0.3391506285604395, 'len_char_mean': 30.34453781512605, 'len_char_std': 34.00072895093229, 'len_words_mean': 5.243697478991597, 'len_words_std': 5.712472676247232, 'noun_ratio_mean': 0.45974401346866, 'noun_ratio_std': 0.3643449083314953, 'verb_ratio_mean': 0.1640937542355235, 'verb_ratio_std': 0.22524653169954653, 'duration_total': 1014.62, 'participant': '328'}
# Loaded data: {'polarity_mean': 0.18832773331319844, 'polarity_std': 0.3123365188426385, 'subjectivity_mean': 0.29380785289215516, 'subjectivity_std': 0.32244645086895274, 'len_char_mean': 30.333333333333332, 'len_char_std': 46.43431741000757, 'len_words_mean': 5.0310077519379846, 'len_words_std': 7.3110981396608254, 'noun_ratio_mean': 0.43178312536481134, 'noun_ratio_std': 0.3526221908996851, 'verb_ratio_mean': 0.16563240260853795, 'verb_ratio_std': 0.21158191706858254, 'duration_total': 651.98, 'participant': '329'}
# Loaded data: {'polarity_mean': 0.1139635713219457, 'polarity_std': 0.2556092935102936, 'subjectivity_mean': 0.2042034969682753, 'subjectivity_std': 0.2960759754156566, 'len_char_mean': 13.798029556650246, 'len_char_std': 13.44344943575848, 'len_words_mean': 2.3497536945812807, 'len_words_std': 2.0707384817560586, 'noun_ratio_mean': 0.4719231370709204, 'noun_ratio_std': 0.4069845167435697, 'verb_ratio_mean': 0.15123934631323793, 'verb_ratio_std': 0.24189911524357635, 'duration_total': 695.77, 'participant': '330'}
# Loaded data: {'polarity_mean': 0.11321392577278228, 'polarity_std': 0.2798128200997047, 'subjectivity_mean': 0.29295732387940904, 'subjectivity_std': 0.3252734794840841, 'len_char_mean': 23.77578475336323, 'len_char_std': 27.254786275890165, 'len_words_mean': 4.116591928251121, 'len_words_std': 4.556437189763385, 'noun_ratio_mean': 0.4726593246712408, 'noun_ratio_std': 0.36834181555588663, 'verb_ratio_mean': 0.1464407249273867, 'verb_ratio_std': 0.18999648904829827, 'duration_total': 790.63, 'participant': '331'}
# Loaded data: {'polarity_mean': 0.10730715068064466, 'polarity_std': 0.2865612716886116, 'subjectivity_mean': 0.24189347577901793, 'subjectivity_std': 0.332617057276853, 'len_char_mean': 16.269076305220885, 'len_char_std': 18.309940439592154, 'len_words_mean': 2.783132530120482, 'len_words_std': 2.933599267762478, 'noun_ratio_mean': 0.47208726681618246, 'noun_ratio_std': 0.39328496607598906, 'verb_ratio_mean': 0.14154677874557392, 'verb_ratio_std': 0.23397688032928635, 'duration_total': 746.04, 'participant': '332'}
# Loaded data: {'polarity_mean': 0.128376272647106, 'polarity_std': 0.28664718494202895, 'subjectivity_mean': 0.28636802240968906, 'subjectivity_std': 0.32747417722453986, 'len_char_mean': 23.26068376068376, 'len_char_std': 24.21196617311846, 'len_words_mean': 4.0, 'len_words_std': 3.8923276573632233, 'noun_ratio_mean': 0.4694411463061736, 'noun_ratio_std': 0.3454605725867128, 'verb_ratio_mean': 0.17652786196189388, 'verb_ratio_std': 0.22167502057528754, 'duration_total': 908.03, 'participant': '334'}
# Loaded data: {'polarity_mean': 0.11484842893883483, 'polarity_std': 0.30301264104405545, 'subjectivity_mean': 0.24901890145524833, 'subjectivity_std': 0.3310095621877683, 'len_char_mean': 19.85239852398524, 'len_char_std': 26.002285935190475, 'len_words_mean': 3.302583025830258, 'len_words_std': 4.093892556751988, 'noun_ratio_mean': 0.4646976795420562, 'noun_ratio_std': 0.3923708337057712, 'verb_ratio_mean': 0.13599223053538792, 'verb_ratio_std': 0.20276077360462857, 'duration_total': 785.4100000000001, 'participant': '335'}
# Loaded data: {'polarity_mean': 0.10684965352934103, 'polarity_std': 0.292441930747546, 'subjectivity_mean': 0.26488608180014434, 'subjectivity_std': 0.3337172696114487, 'len_char_mean': 17.545833333333334, 'len_char_std': 17.91769839071529, 'len_words_mean': 3.0208333333333335, 'len_words_std': 2.8335230472214747, 'noun_ratio_mean': 0.4327522246272247, 'noun_ratio_std': 0.3820902882144527, 'verb_ratio_mean': 0.13891248797498798, 'verb_ratio_std': 0.20214468106525546, 'duration_total': 849.02, 'participant': '336'}
# Loaded data: {'polarity_mean': 0.051172120363296825, 'polarity_std': 0.26234996266638, 'subjectivity_mean': 0.24427897266132562, 'subjectivity_std': 0.302166159628229, 'len_char_mean': 30.997737556561084, 'len_char_std': 30.329744788013382, 'len_words_mean': 5.382352941176471, 'len_words_std': 5.096880543676748, 'noun_ratio_mean': 0.399182129148111, 'noun_ratio_std': 0.3326348665341999, 'verb_ratio_mean': 0.19286414347907493, 'verb_ratio_std': 0.2173947230388044, 'duration_total': 1811.62, 'participant': '337'}
# Loaded data: {'polarity_mean': 0.13272451481690611, 'polarity_std': 0.3085428140329438, 'subjectivity_mean': 0.32156227126335823, 'subjectivity_std': 0.346947978504983, 'len_char_mean': 27.166666666666668, 'len_char_std': 30.938975332858096, 'len_words_mean': 4.586956521739131, 'len_words_std': 5.052611178462438, 'noun_ratio_mean': 0.4501829479131269, 'noun_ratio_std': 0.3601103913909151, 'verb_ratio_mean': 0.17119752701594135, 'verb_ratio_std': 0.21104050888860698, 'duration_total': 545.48, 'participant': '338'}
# Loaded data: {'polarity_mean': 0.1407277016021651, 'polarity_std': 0.28710454412507913, 'subjectivity_mean': 0.26501883488471467, 'subjectivity_std': 0.3198610420827427, 'len_char_mean': 18.36051502145923, 'len_char_std': 19.095688800566794, 'len_words_mean': 3.0, 'len_words_std': 2.897680404071148, 'noun_ratio_mean': 0.38424602936405505, 'noun_ratio_std': 0.36597220177112083, 'verb_ratio_mean': 0.15332880638674629, 'verb_ratio_std': 0.2065059627047567, 'duration_total': 810.33, 'participant': '339'}
# Loaded data: {'polarity_mean': 0.20327719155844157, 'polarity_std': 0.31048416819682756, 'subjectivity_mean': 0.321070807542847, 'subjectivity_std': 0.33171302777312556, 'len_char_mean': 20.07236842105263, 'len_char_std': 18.874665726151637, 'len_words_mean': 3.6184210526315788, 'len_words_std': 3.1975450237887966, 'noun_ratio_mean': 0.4688972029432555, 'noun_ratio_std': 0.3599030270517623, 'verb_ratio_mean': 0.13960341559025768, 'verb_ratio_std': 0.1814295315068105, 'duration_total': 536.89, 'participant': '340'}
# Loaded data: {'polarity_mean': 0.08944225184034967, 'polarity_std': 0.2779303713707044, 'subjectivity_mean': 0.24516587436650839, 'subjectivity_std': 0.3147247854800221, 'len_char_mean': 18.695652173913043, 'len_char_std': 19.883335624917727, 'len_words_mean': 3.210144927536232, 'len_words_std': 3.360633919747284, 'noun_ratio_mean': 0.4752159312341538, 'noun_ratio_std': 0.3906493884519953, 'verb_ratio_mean': 0.1370601413600135, 'verb_ratio_std': 0.20197719160258534, 'duration_total': 790.29, 'participant': '341'}
# Loaded data: {'polarity_mean': 0.09380892508518558, 'polarity_std': 0.26477449145009924, 'subjectivity_mean': 0.20667816368971828, 'subjectivity_std': 0.29615632031313704, 'len_char_mean': 14.231092436974789, 'len_char_std': 13.889602388036472, 'len_words_mean': 2.5210084033613445, 'len_words_std': 2.2514832972739933, 'noun_ratio_mean': 0.4698691014867485, 'noun_ratio_std': 0.39657451195309756, 'verb_ratio_mean': 0.14018671571192579, 'verb_ratio_std': 0.2118587515048013, 'duration_total': 786.51, 'participant': '343'}
# Loaded data: {'polarity_mean': 0.10302639704107674, 'polarity_std': 0.26975630799949823, 'subjectivity_mean': 0.2499309278601983, 'subjectivity_std': 0.2984851553006761, 'len_char_mean': 23.94661921708185, 'len_char_std': 26.005507609533144, 'len_words_mean': 4.124555160142349, 'len_words_std': 4.407234543255881, 'noun_ratio_mean': 0.4369524401873762, 'noun_ratio_std': 0.355113975259099, 'verb_ratio_mean': 0.1839421155077039, 'verb_ratio_std': 0.23952105357648318, 'duration_total': 1015.4900000000001, 'participant': '344'}
# Loaded data: {'polarity_mean': 0.14089655101925652, 'polarity_std': 0.32065414878493853, 'subjectivity_mean': 0.3105723896126929, 'subjectivity_std': 0.32418855376684624, 'len_char_mean': 30.804469273743017, 'len_char_std': 34.330037002420106, 'len_words_mean': 5.396648044692737, 'len_words_std': 5.925017417518994, 'noun_ratio_mean': 0.45389803616043306, 'noun_ratio_std': 0.35547309696631163, 'verb_ratio_mean': 0.18669039083575464, 'verb_ratio_std': 0.21307362931575236, 'duration_total': 744.737, 'participant': '345'}
# Loaded data: {'polarity_mean': 0.06608007252487771, 'polarity_std': 0.2866724040304757, 'subjectivity_mean': 0.23390130432338227, 'subjectivity_std': 0.3280820396395881, 'len_char_mean': 16.94025974025974, 'len_char_std': 20.53335865465493, 'len_words_mean': 2.979220779220779, 'len_words_std': 3.4677959522200505, 'noun_ratio_mean': 0.3377989693440419, 'noun_ratio_std': 0.365728443344016, 'verb_ratio_mean': 0.17005837766341966, 'verb_ratio_std': 0.23655091647691742, 'duration_total': 1171.64, 'participant': '346'}
# Loaded data: {'polarity_mean': 0.1464736349593732, 'polarity_std': 0.31181653371101736, 'subjectivity_mean': 0.3307929183977842, 'subjectivity_std': 0.3404517900658246, 'len_char_mean': 17.838926174496645, 'len_char_std': 16.625471793384424, 'len_words_mean': 3.221476510067114, 'len_words_std': 2.9679496006864343, 'noun_ratio_mean': 0.41376008406209747, 'noun_ratio_std': 0.3703930164743842, 'verb_ratio_mean': 0.1479076479076479, 'verb_ratio_std': 0.20964589052187269, 'duration_total': 538.59, 'participant': '347'}
# Loaded data: {'polarity_mean': 0.12939770888496616, 'polarity_std': 0.32670651577565174, 'subjectivity_mean': 0.29418168333823674, 'subjectivity_std': 0.3360893581976338, 'len_char_mean': 21.266990291262136, 'len_char_std': 24.52259441313508, 'len_words_mean': 3.7475728155339807, 'len_words_std': 3.9980933177702185, 'noun_ratio_mean': 0.448349382279683, 'noun_ratio_std': 0.3692462488755374, 'verb_ratio_mean': 0.1729452121485866, 'verb_ratio_std': 0.2283431578314553, 'duration_total': 665.24, 'participant': '348'}
# Loaded data: {'polarity_mean': 0.11057555597996772, 'polarity_std': 0.26079022607202845, 'subjectivity_mean': 0.21075849531731886, 'subjectivity_std': 0.2917681045569168, 'len_char_mean': 17.895424836601308, 'len_char_std': 18.257956145357767, 'len_words_mean': 3.0326797385620914, 'len_words_std': 2.955224993578341, 'noun_ratio_mean': 0.4695121690219729, 'noun_ratio_std': 0.39046706373883877, 'verb_ratio_mean': 0.15367279779044485, 'verb_ratio_std': 0.22646408187537717, 'duration_total': 1136.16, 'participant': '349'}
# Loaded data: {'polarity_mean': 0.11821514504887146, 'polarity_std': 0.2945712287733713, 'subjectivity_mean': 0.2854174919681995, 'subjectivity_std': 0.3351875086375671, 'len_char_mean': 25.297169811320753, 'len_char_std': 28.44169876992045, 'len_words_mean': 4.113207547169812, 'len_words_std': 4.295530035801586, 'noun_ratio_mean': 0.4390946421577592, 'noun_ratio_std': 0.36555907593633374, 'verb_ratio_mean': 0.17680216062276927, 'verb_ratio_std': 0.21471997653841615, 'duration_total': 817.0, 'participant': '350'}
# Loaded data: {'polarity_mean': 0.13678590598880452, 'polarity_std': 0.3042204237226019, 'subjectivity_mean': 0.2836249543979013, 'subjectivity_std': 0.33073505120805513, 'len_char_mean': 22.879227053140095, 'len_char_std': 26.479702858554187, 'len_words_mean': 3.8067632850241546, 'len_words_std': 4.167762624965934, 'noun_ratio_mean': 0.43182732159265563, 'noun_ratio_std': 0.3564826111888835, 'verb_ratio_mean': 0.14332825682267059, 'verb_ratio_std': 0.20453261305091774, 'duration_total': 717.75, 'participant': '351'}
# Loaded data: {'polarity_mean': 0.13295145520329346, 'polarity_std': 0.30707320548988176, 'subjectivity_mean': 0.3679900767125032, 'subjectivity_std': 0.341434913587961, 'len_char_mean': 43.26470588235294, 'len_char_std': 38.30699293942299, 'len_words_mean': 7.117647058823529, 'len_words_std': 6.160878753493737, 'noun_ratio_mean': 0.3877628105392857, 'noun_ratio_std': 0.29071256362624265, 'verb_ratio_mean': 0.20751764131197523, 'verb_ratio_std': 0.1815272942797232, 'duration_total': 711.06, 'participant': '352'}
# Loaded data: {'polarity_mean': 0.11581895853579526, 'polarity_std': 0.2590885568936734, 'subjectivity_mean': 0.22582926568895956, 'subjectivity_std': 0.2962033199946134, 'len_char_mean': 24.229591836734695, 'len_char_std': 27.3640854244135, 'len_words_mean': 4.01530612244898, 'len_words_std': 4.4126589935081055, 'noun_ratio_mean': 0.41389540731377467, 'noun_ratio_std': 0.36573933832047795, 'verb_ratio_mean': 0.16959103255021626, 'verb_ratio_std': 0.21508435061597725, 'duration_total': 739.7, 'participant': '353'}
# Loaded data: {'polarity_mean': 0.11090160584863976, 'polarity_std': 0.2829778990416202, 'subjectivity_mean': 0.2394871434278214, 'subjectivity_std': 0.31928023894179863, 'len_char_mean': 16.152542372881356, 'len_char_std': 17.68391689629505, 'len_words_mean': 2.8361581920903953, 'len_words_std': 2.9736041297199622, 'noun_ratio_mean': 0.4394648509055289, 'noun_ratio_std': 0.394810797475797, 'verb_ratio_mean': 0.1469396579566071, 'verb_ratio_std': 0.2308225183337289, 'duration_total': 533.76, 'participant': '354'}
# Loaded data: {'polarity_mean': 0.10129799195810431, 'polarity_std': 0.28240319329987684, 'subjectivity_mean': 0.26262828931368254, 'subjectivity_std': 0.3341373143393768, 'len_char_mean': 24.09550561797753, 'len_char_std': 25.212697052889034, 'len_words_mean': 4.0, 'len_words_std': 3.8356048293300056, 'noun_ratio_mean': 0.4397358899724364, 'noun_ratio_std': 0.35119823146008317, 'verb_ratio_mean': 0.16981041660225574, 'verb_ratio_std': 0.20034897943093963, 'duration_total': 630.9399999999999, 'participant': '355'}
# Loaded data: {'polarity_mean': 0.07645428756874541, 'polarity_std': 0.2413017419087935, 'subjectivity_mean': 0.21402794801138175, 'subjectivity_std': 0.3102254553474047, 'len_char_mean': 22.433734939759034, 'len_char_std': 24.311085071731043, 'len_words_mean': 3.7630522088353415, 'len_words_std': 3.906683727054317, 'noun_ratio_mean': 0.4148658861553785, 'noun_ratio_std': 0.3586321978423673, 'verb_ratio_mean': 0.17024187917124992, 'verb_ratio_std': 0.2287817099833041, 'duration_total': 889.9300000000001, 'participant': '356'}
# Loaded data: {'polarity_mean': 0.08596862187635995, 'polarity_std': 0.2101427768764036, 'subjectivity_mean': 0.2148320435076387, 'subjectivity_std': 0.31015384001064006, 'len_char_mean': 17.357142857142858, 'len_char_std': 14.681942261547979, 'len_words_mean': 3.0476190476190474, 'len_words_std': 2.4620548908816566, 'noun_ratio_mean': 0.43301295265580975, 'noun_ratio_std': 0.37360128165648065, 'verb_ratio_mean': 0.15369855012712155, 'verb_ratio_std': 0.19627933060443933, 'duration_total': 360.935, 'participant': '357'}
# Loaded data: {'polarity_mean': 0.0959275823514234, 'polarity_std': 0.25541139913840644, 'subjectivity_mean': 0.2353429517502365, 'subjectivity_std': 0.3077986637839527, 'len_char_mean': 22.516556291390728, 'len_char_std': 24.272303641430707, 'len_words_mean': 3.7019867549668874, 'len_words_std': 3.7785265240774404, 'noun_ratio_mean': 0.4689403674633719, 'noun_ratio_std': 0.35582203807765433, 'verb_ratio_mean': 0.16438088411336932, 'verb_ratio_std': 0.23105610733511422, 'duration_total': 585.035, 'participant': '358'}
# Loaded data: {'polarity_mean': 0.08283902722386974, 'polarity_std': 0.2977828755977991, 'subjectivity_mean': 0.27793501664564657, 'subjectivity_std': 0.3354053204879594, 'len_char_mean': 31.70472440944882, 'len_char_std': 34.751338833407026, 'len_words_mean': 5.515748031496063, 'len_words_std': 6.030697823358117, 'noun_ratio_mean': 0.45763507045494645, 'noun_ratio_std': 0.3488965945428964, 'verb_ratio_mean': 0.16891456074329267, 'verb_ratio_std': 0.19087238493318145, 'duration_total': 975.37, 'participant': '359'}
# Loaded data: {'polarity_mean': 0.1576983257706149, 'polarity_std': 0.3425765248797964, 'subjectivity_mean': 0.3277137771866688, 'subjectivity_std': 0.3244342060905706, 'len_char_mean': 33.42168674698795, 'len_char_std': 30.960683361214087, 'len_words_mean': 5.506024096385542, 'len_words_std': 5.051861511474715, 'noun_ratio_mean': 0.4285133954163012, 'noun_ratio_std': 0.3186096388087644, 'verb_ratio_mean': 0.2102720100593949, 'verb_ratio_std': 0.20155773362164142, 'duration_total': 379.85999999999996, 'participant': '360'}
# Loaded data: {'polarity_mean': 0.17707674505343995, 'polarity_std': 0.2899498516704786, 'subjectivity_mean': 0.36447271596106345, 'subjectivity_std': 0.3342586972564043, 'len_char_mean': 38.50847457627118, 'len_char_std': 34.260127522006314, 'len_words_mean': 6.466101694915254, 'len_words_std': 5.933653410251441, 'noun_ratio_mean': 0.4104900131993851, 'noun_ratio_std': 0.2993947046281311, 'verb_ratio_mean': 0.1809437852222, 'verb_ratio_std': 0.19231796940523777, 'duration_total': 599.5400000000001, 'participant': '361'}
# Loaded data: {'polarity_mean': 0.11300437934158863, 'polarity_std': 0.2884198319348704, 'subjectivity_mean': 0.24957055326241376, 'subjectivity_std': 0.31436676397429425, 'len_char_mean': 27.124031007751938, 'len_char_std': 23.775975187655938, 'len_words_mean': 4.5271317829457365, 'len_words_std': 3.9530002833683255, 'noun_ratio_mean': 0.41380741161862916, 'noun_ratio_std': 0.3187352295217568, 'verb_ratio_mean': 0.18229398407236982, 'verb_ratio_std': 0.2097901562783596, 'duration_total': 536.0799999999999, 'participant': '362'}
# Loaded data: {'polarity_mean': 0.07325456035510383, 'polarity_std': 0.289672022414238, 'subjectivity_mean': 0.2899180351653178, 'subjectivity_std': 0.33996809578022313, 'len_char_mean': 32.53478260869565, 'len_char_std': 29.188532005011105, 'len_words_mean': 5.104347826086957, 'len_words_std': 4.64057275685626, 'noun_ratio_mean': 0.42911286780852, 'noun_ratio_std': 0.3212475365462461, 'verb_ratio_mean': 0.17234950436037394, 'verb_ratio_std': 0.21232146420096626, 'duration_total': 1069.252, 'participant': '363'}
# Loaded data: {'polarity_mean': 0.09828815945623556, 'polarity_std': 0.23894659496780932, 'subjectivity_mean': 0.2462839938328839, 'subjectivity_std': 0.30743918409745125, 'len_char_mean': 29.668076109936575, 'len_char_std': 28.26587179563145, 'len_words_mean': 4.723044397463002, 'len_words_std': 4.513801532115672, 'noun_ratio_mean': 0.3851324551950129, 'noun_ratio_std': 0.3189903173311353, 'verb_ratio_mean': 0.175197727866002, 'verb_ratio_std': 0.20874177498543342, 'duration_total': 1640.307, 'participant': '364'}
# Loaded data: {'polarity_mean': 0.06971918199190927, 'polarity_std': 0.2865634239876334, 'subjectivity_mean': 0.22802207313570952, 'subjectivity_std': 0.3338949775501641, 'len_char_mean': 20.13022113022113, 'len_char_std': 20.03667193834282, 'len_words_mean': 3.383292383292383, 'len_words_std': 3.255236928187631, 'noun_ratio_mean': 0.3654552586370769, 'noun_ratio_std': 0.3439623613376444, 'verb_ratio_mean': 0.2278994483539938, 'verb_ratio_std': 0.2765310041069134, 'duration_total': 1309.492, 'participant': '365'}
# Loaded data: {'polarity_mean': 0.07734815044506055, 'polarity_std': 0.2611624451940509, 'subjectivity_mean': 0.22710128978387406, 'subjectivity_std': 0.3169282508639323, 'len_char_mean': 26.365168539325843, 'len_char_std': 29.677066029857595, 'len_words_mean': 4.297752808988764, 'len_words_std': 4.803882878521855, 'noun_ratio_mean': 0.4308652297371773, 'noun_ratio_std': 0.36277324742633266, 'verb_ratio_mean': 0.16552198727697476, 'verb_ratio_std': 0.22378263007879, 'duration_total': 1246.201, 'participant': '366'}
# Loaded data: {'polarity_mean': 0.03842109828443161, 'polarity_std': 0.23161804898128552, 'subjectivity_mean': 0.2626766474266475, 'subjectivity_std': 0.31774057383804827, 'len_char_mean': 25.506666666666668, 'len_char_std': 26.463360470947947, 'len_words_mean': 4.197333333333333, 'len_words_std': 4.265706219885192, 'noun_ratio_mean': 0.32796080917133547, 'noun_ratio_std': 0.326701336469172, 'verb_ratio_mean': 0.1883511128706175, 'verb_ratio_std': 0.21985890125655105, 'duration_total': 1566.5549999999998, 'participant': '367'}
# Loaded data: {'polarity_mean': 0.08123535456935138, 'polarity_std': 0.28937901259474286, 'subjectivity_mean': 0.26385493067618865, 'subjectivity_std': 0.31020039459118476, 'len_char_mean': 36.617834394904456, 'len_char_std': 35.34350558431434, 'len_words_mean': 6.414012738853503, 'len_words_std': 6.226855765815662, 'noun_ratio_mean': 0.39042262301723907, 'noun_ratio_std': 0.32822803615541496, 'verb_ratio_mean': 0.21614686182376183, 'verb_ratio_std': 0.22225293417669045, 'duration_total': 1292.776, 'participant': '368'}
# Loaded data: {'polarity_mean': 0.18512374488936992, 'polarity_std': 0.3203415204644097, 'subjectivity_mean': 0.30056091670675006, 'subjectivity_std': 0.34206049256462423, 'len_char_mean': 28.65625, 'len_char_std': 28.929384694121786, 'len_words_mean': 4.958333333333333, 'len_words_std': 4.910168642476647, 'noun_ratio_mean': 0.4184221986059415, 'noun_ratio_std': 0.34158137598570393, 'verb_ratio_mean': 0.19943238391259868, 'verb_ratio_std': 0.2305681948727681, 'duration_total': 993.175, 'participant': '369'}
# Loaded data: {'polarity_mean': 0.1372534914876464, 'polarity_std': 0.30258611545448544, 'subjectivity_mean': 0.36999769661741494, 'subjectivity_std': 0.32974730754782544, 'len_char_mean': 48.859154929577464, 'len_char_std': 39.41504924301956, 'len_words_mean': 7.938967136150235, 'len_words_std': 6.434065652054897, 'noun_ratio_mean': 0.40143952352114026, 'noun_ratio_std': 0.28330831360002157, 'verb_ratio_mean': 0.20666397356045746, 'verb_ratio_std': 0.18726434043744178, 'duration_total': 1160.3600000000001, 'participant': '370'}
# Loaded data: {'polarity_mean': 0.10666795174305903, 'polarity_std': 0.29880640926360247, 'subjectivity_mean': 0.2497256903801968, 'subjectivity_std': 0.3267109092906559, 'len_char_mean': 20.63519313304721, 'len_char_std': 21.90103046468648, 'len_words_mean': 3.188841201716738, 'len_words_std': 3.2679814152943023, 'noun_ratio_mean': 0.46402002861230324, 'noun_ratio_std': 0.3636310836347293, 'verb_ratio_mean': 0.12664752986641398, 'verb_ratio_std': 0.17716763873828562, 'duration_total': 859.28, 'participant': '371'}
# Loaded data: {'polarity_mean': 0.07703010319017514, 'polarity_std': 0.26293736510594806, 'subjectivity_mean': 0.20648382160072806, 'subjectivity_std': 0.3047913343509354, 'len_char_mean': 20.47242206235012, 'len_char_std': 21.239812764781494, 'len_words_mean': 3.3501199040767387, 'len_words_std': 3.381540135428161, 'noun_ratio_mean': 0.4294014438798611, 'noun_ratio_std': 0.35864720407613054, 'verb_ratio_mean': 0.18617963770841467, 'verb_ratio_std': 0.2521111160474084, 'duration_total': 1468.049, 'participant': '372'}
# Loaded data: {'polarity_mean': 0.12526887880815082, 'polarity_std': 0.28176523288665617, 'subjectivity_mean': 0.32220175551353714, 'subjectivity_std': 0.31631894265245714, 'len_char_mean': 43.7816091954023, 'len_char_std': 37.55552564711749, 'len_words_mean': 7.153256704980843, 'len_words_std': 6.314168966514537, 'noun_ratio_mean': 0.4408043773388159, 'noun_ratio_std': 0.3098362672273134, 'verb_ratio_mean': 0.18131840761039578, 'verb_ratio_std': 0.18319971150754433, 'duration_total': 1213.5900000000001, 'participant': '373'}
# Loaded data: {'polarity_mean': 0.08922099866832806, 'polarity_std': 0.2624028620710524, 'subjectivity_mean': 0.25049460801315404, 'subjectivity_std': 0.3219684286927543, 'len_char_mean': 26.922848664688427, 'len_char_std': 30.525847462265972, 'len_words_mean': 4.353115727002967, 'len_words_std': 4.87979898971462, 'noun_ratio_mean': 0.4196140201576532, 'noun_ratio_std': 0.35457296548377315, 'verb_ratio_mean': 0.15455285576804903, 'verb_ratio_std': 0.22566841086322703, 'duration_total': 1242.38, 'participant': '374'}
# Loaded data: {'polarity_mean': 0.11055092750816435, 'polarity_std': 0.31684116262689876, 'subjectivity_mean': 0.2692523923444976, 'subjectivity_std': 0.32424181156438775, 'len_char_mean': 25.401315789473685, 'len_char_std': 24.230477187775293, 'len_words_mean': 3.8947368421052633, 'len_words_std': 3.684867740016613, 'noun_ratio_mean': 0.4627926349965823, 'noun_ratio_std': 0.3187016427504831, 'verb_ratio_mean': 0.18703339788866105, 'verb_ratio_std': 0.20813617472673787, 'duration_total': 568.993, 'participant': '375'}
# Loaded data: {'polarity_mean': 0.064054057714772, 'polarity_std': 0.26751358049382723, 'subjectivity_mean': 0.2394730379002357, 'subjectivity_std': 0.325601365587342, 'len_char_mean': 26.86813186813187, 'len_char_std': 27.155411438501744, 'len_words_mean': 4.252747252747253, 'len_words_std': 4.315481893018696, 'noun_ratio_mean': 0.3767569080109481, 'noun_ratio_std': 0.3333447742935797, 'verb_ratio_mean': 0.1629718829137058, 'verb_ratio_std': 0.2029395482328684, 'duration_total': 959.4100000000001, 'participant': '376'}
# Loaded data: {'polarity_mean': 0.11081383557210762, 'polarity_std': 0.2658718641429114, 'subjectivity_mean': 0.27115404968805706, 'subjectivity_std': 0.33823028177757297, 'len_char_mean': 29.941176470588236, 'len_char_std': 28.208286797314752, 'len_words_mean': 4.570588235294117, 'len_words_std': 4.3556174972961115, 'noun_ratio_mean': 0.4497913713148593, 'noun_ratio_std': 0.3299396566180661, 'verb_ratio_mean': 0.178359767754269, 'verb_ratio_std': 0.20501834269671892, 'duration_total': 1283.192, 'participant': '377'}
# Loaded data: {'polarity_mean': 0.13811223218734428, 'polarity_std': 0.2937750005377068, 'subjectivity_mean': 0.3296493927099309, 'subjectivity_std': 0.3380917211162101, 'len_char_mean': 27.717488789237667, 'len_char_std': 25.1467048504687, 'len_words_mean': 4.439461883408072, 'len_words_std': 4.006151090008088, 'noun_ratio_mean': 0.4652256346438551, 'noun_ratio_std': 0.33925233451567804, 'verb_ratio_mean': 0.13802195889757843, 'verb_ratio_std': 0.19053988627000315, 'duration_total': 819.2, 'participant': '378'}
# Loaded data: {'polarity_mean': 0.12747901855371369, 'polarity_std': 0.29676149223300274, 'subjectivity_mean': 0.30246825378494585, 'subjectivity_std': 0.3256774575672991, 'len_char_mean': 33.52439024390244, 'len_char_std': 27.73739925930105, 'len_words_mean': 5.429878048780488, 'len_words_std': 4.636112468761187, 'noun_ratio_mean': 0.4443207027216032, 'noun_ratio_std': 0.3020673334709657, 'verb_ratio_mean': 0.22413775052692786, 'verb_ratio_std': 0.19971060330460894, 'duration_total': 951.569, 'participant': '379'}
# Loaded data: {'polarity_mean': 0.09739454248042034, 'polarity_std': 0.27479733103440634, 'subjectivity_mean': 0.25569262692354294, 'subjectivity_std': 0.32721608295756305, 'len_char_mean': 26.248091603053435, 'len_char_std': 24.96932018231686, 'len_words_mean': 4.236641221374046, 'len_words_std': 3.985283389489326, 'noun_ratio_mean': 0.421921912347284, 'noun_ratio_std': 0.3540831248077314, 'verb_ratio_mean': 0.16927440751516684, 'verb_ratio_std': 0.20423154052270398, 'duration_total': 1036.897, 'participant': '381'}
# Loaded data: {'polarity_mean': 0.13308141432104087, 'polarity_std': 0.29179632778552356, 'subjectivity_mean': 0.2814921143863053, 'subjectivity_std': 0.33866255223769753, 'len_char_mean': 23.66390041493776, 'len_char_std': 24.18503117750125, 'len_words_mean': 3.5850622406639006, 'len_words_std': 3.7095070562376127, 'noun_ratio_mean': 0.4323936091570946, 'noun_ratio_std': 0.3697987036791756, 'verb_ratio_mean': 0.13506956390773817, 'verb_ratio_std': 0.19820642562370408, 'duration_total': 775.68, 'participant': '382'}
# Loaded data: {'polarity_mean': 0.10689805055142228, 'polarity_std': 0.260292118468144, 'subjectivity_mean': 0.2718537182846394, 'subjectivity_std': 0.3288342864232652, 'len_char_mean': 28.832236842105264, 'len_char_std': 28.951788996003895, 'len_words_mean': 4.509868421052632, 'len_words_std': 4.498613792629582, 'noun_ratio_mean': 0.4683433483147309, 'noun_ratio_std': 0.3486563278870104, 'verb_ratio_mean': 0.15423713475795112, 'verb_ratio_std': 0.20624296696368752, 'duration_total': 1339.413, 'participant': '383'}
# Loaded data: {'polarity_mean': 0.1476967476967477, 'polarity_std': 0.3009213401414586, 'subjectivity_mean': 0.28792308881594597, 'subjectivity_std': 0.34626926623615073, 'len_char_mean': 24.523809523809526, 'len_char_std': 22.07957660556996, 'len_words_mean': 3.8095238095238093, 'len_words_std': 3.4449959650019255, 'noun_ratio_mean': 0.4420344206058492, 'noun_ratio_std': 0.35018938997518734, 'verb_ratio_mean': 0.17784094212665638, 'verb_ratio_std': 0.21388865907632815, 'duration_total': 962.635, 'participant': '446'}
# Loaded data: {'polarity_mean': 0.12710864135864136, 'polarity_std': 0.2964832299641576, 'subjectivity_mean': 0.2938280608280608, 'subjectivity_std': 0.33963750985277624, 'len_char_mean': 31.923076923076923, 'len_char_std': 28.712747820279404, 'len_words_mean': 4.923076923076923, 'len_words_std': 4.5406787686004995, 'noun_ratio_mean': 0.4820466629063914, 'noun_ratio_std': 0.3369838571812179, 'verb_ratio_mean': 0.1621118457543797, 'verb_ratio_std': 0.19423272349046325, 'duration_total': 782.0, 'participant': '447'}
# Loaded data: {'polarity_mean': 0.0798980101201862, 'polarity_std': 0.25115846909775263, 'subjectivity_mean': 0.2176048423245267, 'subjectivity_std': 0.28743911530397315, 'len_char_mean': 28.45514950166113, 'len_char_std': 26.20741908431481, 'len_words_mean': 4.687707641196013, 'len_words_std': 4.357615754160535, 'noun_ratio_mean': 0.3693320324280848, 'noun_ratio_std': 0.31300104481813934, 'verb_ratio_mean': 0.2424452103170102, 'verb_ratio_std': 0.2558903773161318, 'duration_total': 1175.02, 'participant': '448'}

# %%
import numpy as np

# Combine audio and text features
features = audio_features
labels = np.array(labels)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    features, labels, test_size=0.2, random_state=42, stratify=labels
)

# %%
import os
import numpy as np
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# ---------------- Logistic Regression ----------------
logreg_model = make_pipeline(
    StandardScaler(),
    LogisticRegression(max_iter=500, solver='liblinear')
)
logreg_model.fit(X_train, y_train)
logreg_preds = logreg_model.predict(X_test)
logreg_acc = accuracy_score(y_test, logreg_preds)
print("LogReg Accuracy:", logreg_acc)

# ---------------- Support Vector Machine -------------
svm_model = make_pipeline(
    StandardScaler(),
    SVC(kernel='rbf', C=10, gamma='scale', probability=True)
)
svm_model.fit(X_train, y_train)
svm_preds = svm_model.predict(X_test)
svm_acc = accuracy_score(y_test, svm_preds)
print("SVM Accuracy:", svm_acc)

# ---------------- Decision Tree ----------------------
dt_model = make_pipeline(
    StandardScaler(),
    DecisionTreeClassifier(max_depth=None, random_state=42)
)
dt_model.fit(X_train, y_train)
dt_preds = dt_model.predict(X_test)
dt_acc = accuracy_score(y_test, dt_preds)
print("Decision Tree Accuracy:", dt_acc)

# ---------------- Gaussian Naive Bayes ---------------
gnb_model = make_pipeline(
    StandardScaler(),
    GaussianNB()
)
gnb_model.fit(X_train, y_train)
gnb_preds = gnb_model.predict(X_test)
gnb_acc = accuracy_score(y_test, gnb_preds)
print("GaussianNB Accuracy:", gnb_acc)

# ---------------- Random Forest ----------------------
rf_model = make_pipeline(
    StandardScaler(),
    RandomForestClassifier(n_estimators=100, random_state=42)
)
rf_model.fit(X_train, y_train)
rf_preds = rf_model.predict(X_test)
rf_acc = accuracy_score(y_test, rf_preds)
print("Random Forest Accuracy:", rf_acc)
# Out:
# LogReg Accuracy: 0.6470588235294118
# SVM Accuracy: 0.6470588235294118
# Decision Tree Accuracy: 0.5882352941176471
# GaussianNB Accuracy: 0.6470588235294118
# Random Forest Accuracy: 0.5294117647058824

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import accuracy_score

# Resample with SMOTE (imbalanced dataset handling)
smote = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# Scaling the data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_resampled)
X_test_scaled = scaler.transform(X_test)

# Build the deep learning model (Neural Network)
model = Sequential()

# Input layer with BatchNormalization
model.add(Dense(64, input_dim=X_train_scaled.shape[1], activation='relu'))  
model.add(BatchNormalization())  # Adding BatchNormalization

# Hidden layers
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.5))  # Adding Dropout
model.add(Dense(16, activation='relu'))
model.add(Dropout(0.5))  # Adding Dropout

# Output layer (binary classification)
model.add(Dense(1, activation='sigmoid'))

# Compile the model with a lower learning rate
model.compile(optimizer=Adam(learning_rate=0.0005), loss='binary_crossentropy', metrics=['accuracy'])

# Early stopping to avoid overfitting
# early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Train the model
model.fit(X_train_scaled, y_train_resampled, epochs=50, batch_size=32, 
          validation_data=(X_test_scaled, y_test))

# Evaluate the model on the test set
y_pred_prob = model.predict(X_test_scaled)
y_pred = (y_pred_prob > 0.5).astype(int)  # Convert probabilities to binary labels

# Print accuracy
from sklearn.metrics import classification_report

# Classification report
print("📋 Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Epoch 1/50
# 3/3 [==============================] - 1s 77ms/step - loss: 1.0741 - accuracy: 0.4595 - val_loss: 0.6808 - val_accuracy: 0.5294
# Epoch 2/50
# 3/3 [==============================] - 0s 15ms/step - loss: 0.7952 - accuracy: 0.5676 - val_loss: 0.6788 - val_accuracy: 0.4706
# Epoch 3/50
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9440 - accuracy: 0.5405 - val_loss: 0.6750 - val_accuracy: 0.4706
# Epoch 4/50
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9744 - accuracy: 0.5541 - val_loss: 0.6717 - val_accuracy: 0.4706
# Epoch 5/50
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9018 - accuracy: 0.5811 - val_loss: 0.6693 - val_accuracy: 0.5294
# Epoch 6/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.7873 - accuracy: 0.5541 - val_loss: 0.6674 - val_accuracy: 0.5294
# Epoch 7/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.7852 - accuracy: 0.5676 - val_loss: 0.6659 - val_accuracy: 0.5294
# Epoch 8/50
# 3/3 [==============================] - 0s 20ms/step - loss: 0.6835 - accuracy: 0.6081 - val_loss: 0.6654 - val_accuracy: 0.5294
# Epoch 9/50
# 3/3 [==============================] - 0s 20ms/step - loss: 0.7648 - accuracy: 0.5000 - val_loss: 0.6647 - val_accuracy: 0.5294
# Epoch 10/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8640 - accuracy: 0.5000 - val_loss: 0.6639 - val_accuracy: 0.5294
# Epoch 11/50
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9474 - accuracy: 0.5135 - val_loss: 0.6630 - val_accuracy: 0.5294
# Epoch 12/50
# 3/3 [==============================] - 0s 19ms/step - loss: 0.7489 - accuracy: 0.5541 - val_loss: 0.6620 - val_accuracy: 0.5294
# Epoch 13/50
# 3/3 [==============================] - 0s 20ms/step - loss: 0.7560 - accuracy: 0.5270 - val_loss: 0.6612 - val_accuracy: 0.5882
# Epoch 14/50
# 3/3 [==============================] - 0s 21ms/step - loss: 0.8463 - accuracy: 0.5676 - val_loss: 0.6599 - val_accuracy: 0.5882
# Epoch 15/50
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9640 - accuracy: 0.5270 - val_loss: 0.6591 - val_accuracy: 0.5882
# Epoch 16/50
# 3/3 [==============================] - 0s 23ms/step - loss: 0.7594 - accuracy: 0.6486 - val_loss: 0.6582 - val_accuracy: 0.5882
# Epoch 17/50
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7123 - accuracy: 0.6351 - val_loss: 0.6566 - val_accuracy: 0.5882
# Epoch 18/50
# 3/3 [==============================] - 0s 20ms/step - loss: 0.6706 - accuracy: 0.6757 - val_loss: 0.6553 - val_accuracy: 0.5882
# Epoch 19/50
# 3/3 [==============================] - 0s 23ms/step - loss: 0.7444 - accuracy: 0.5946 - val_loss: 0.6535 - val_accuracy: 0.5882
# Epoch 20/50
# 3/3 [==============================] - 0s 22ms/step - loss: 0.8998 - accuracy: 0.4595 - val_loss: 0.6517 - val_accuracy: 0.5882
# Epoch 21/50
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8258 - accuracy: 0.6486 - val_loss: 0.6492 - val_accuracy: 0.6471
# Epoch 22/50
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6764 - accuracy: 0.6216 - val_loss: 0.6463 - val_accuracy: 0.7059
# Epoch 23/50
# 3/3 [==============================] - 0s 16ms/step - loss: 0.7089 - accuracy: 0.6622 - val_loss: 0.6438 - val_accuracy: 0.7059
# Epoch 24/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.7779 - accuracy: 0.5000 - val_loss: 0.6411 - val_accuracy: 0.6471
# Epoch 25/50
# 3/3 [==============================] - 0s 20ms/step - loss: 0.7342 - accuracy: 0.5676 - val_loss: 0.6384 - val_accuracy: 0.6471
# Epoch 26/50
# 3/3 [==============================] - 0s 21ms/step - loss: 0.7884 - accuracy: 0.5541 - val_loss: 0.6359 - val_accuracy: 0.6471
# Epoch 27/50
# 3/3 [==============================] - 0s 19ms/step - loss: 0.7569 - accuracy: 0.5811 - val_loss: 0.6339 - val_accuracy: 0.6471
# Epoch 28/50
# 3/3 [==============================] - 0s 19ms/step - loss: 0.6425 - accuracy: 0.6622 - val_loss: 0.6318 - val_accuracy: 0.6471
# Epoch 29/50
# 3/3 [==============================] - 0s 23ms/step - loss: 0.6742 - accuracy: 0.5946 - val_loss: 0.6300 - val_accuracy: 0.6471
# Epoch 30/50
# 3/3 [==============================] - 0s 24ms/step - loss: 0.6459 - accuracy: 0.6081 - val_loss: 0.6280 - val_accuracy: 0.7059
# Epoch 31/50
# 3/3 [==============================] - 0s 20ms/step - loss: 0.6419 - accuracy: 0.6757 - val_loss: 0.6266 - val_accuracy: 0.7059
# Epoch 32/50
# 3/3 [==============================] - 0s 26ms/step - loss: 0.6029 - accuracy: 0.5946 - val_loss: 0.6259 - val_accuracy: 0.7647
# Epoch 33/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.7584 - accuracy: 0.5541 - val_loss: 0.6250 - val_accuracy: 0.7647
# Epoch 34/50
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7084 - accuracy: 0.6081 - val_loss: 0.6244 - val_accuracy: 0.7647
# Epoch 35/50
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7188 - accuracy: 0.5946 - val_loss: 0.6236 - val_accuracy: 0.8235
# Epoch 36/50
# 3/3 [==============================] - 0s 14ms/step - loss: 0.7695 - accuracy: 0.5135 - val_loss: 0.6229 - val_accuracy: 0.8235
# Epoch 37/50
# 3/3 [==============================] - 0s 13ms/step - loss: 0.5993 - accuracy: 0.6622 - val_loss: 0.6222 - val_accuracy: 0.8235
# Epoch 38/50
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7651 - accuracy: 0.6081 - val_loss: 0.6217 - val_accuracy: 0.8235
# Epoch 39/50
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6234 - accuracy: 0.7297 - val_loss: 0.6211 - val_accuracy: 0.8235
# Epoch 40/50
# 3/3 [==============================] - 0s 16ms/step - loss: 0.7062 - accuracy: 0.6216 - val_loss: 0.6211 - val_accuracy: 0.8235
# Epoch 41/50
# 3/3 [==============================] - 0s 14ms/step - loss: 0.6942 - accuracy: 0.6081 - val_loss: 0.6216 - val_accuracy: 0.8235
# Epoch 42/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6093 - accuracy: 0.6216 - val_loss: 0.6216 - val_accuracy: 0.8235
# Epoch 43/50
# 3/3 [==============================] - 0s 20ms/step - loss: 0.6480 - accuracy: 0.6757 - val_loss: 0.6210 - val_accuracy: 0.8235
# Epoch 44/50
# 3/3 [==============================] - 0s 21ms/step - loss: 0.6328 - accuracy: 0.6486 - val_loss: 0.6206 - val_accuracy: 0.8235
# Epoch 45/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.7127 - accuracy: 0.6351 - val_loss: 0.6199 - val_accuracy: 0.8235
# Epoch 46/50
# 3/3 [==============================] - 0s 22ms/step - loss: 0.6406 - accuracy: 0.7162 - val_loss: 0.6190 - val_accuracy: 0.8235
# Epoch 47/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.7214 - accuracy: 0.5676 - val_loss: 0.6182 - val_accuracy: 0.8235
# Epoch 48/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.6711 - accuracy: 0.6622 - val_loss: 0.6170 - val_accuracy: 0.8235
# Epoch 49/50
# 3/3 [==============================] - 0s 33ms/step - loss: 0.6588 - accuracy: 0.7027 - val_loss: 0.6159 - val_accuracy: 0.8235
# Epoch 50/50
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6850 - accuracy: 0.6486 - val_loss: 0.6144 - val_accuracy: 0.8235
# 1/1 [==============================] - 0s 93ms/step
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      1.00      0.87        10
#            1       1.00      0.57      0.73         7
#
#     accuracy                           0.82        17
#    macro avg       0.88      0.79      0.80        17
# weighted avg       0.86      0.82      0.81        17

# %%
# Save the deep learning model
model.save('depression_model.h5')

# %%
import joblib

# Save the scaler
joblib.dump(scaler, 'scaler.pkl')
# Out:
# ['scaler.pkl']
